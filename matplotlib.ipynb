# %% [markdown]
# <a href="https://www.kaggle.com/code/azizaafrin/matplotlib?scriptVersionId=134717875" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # MatPlotlib
# Matplotlib is a Python library that allows you to create static, animated, and interactive visualizations. Matplotlib is a cross-platform data visualization and graphical plotting package for Python and its numerical extension NumPy. As such, it provides an open source alternative to MATLAB. Developers can also utilize matplotlib's APIs (Application Programming Interfaces) to embed charts in GUI programs.It is of the popular plotting library for python. It allows to control every aspects of a plot.
# Here is the link of the matplotlib official website: [matplotlib](http://https://matplotlib.org/)

# %% [markdown]
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# %matplotlib inline   #to show plot within jupyter notebook
# #or add plt.show() in other than anything in jupyter notebook

# %%
import numpy as np
x=np.linspace(0,5,11)
y=x**2

# %% [markdown]
# # Functional Method

# %%
#functional method for plot
plt.plot(x,y,'r-')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# ## Creating Multiplot

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# # Object-Oriented Method
# ### We have a lot more control on the figure comparing with functional approach.

# %%
fig=plt.figure()

axes=fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Title of the plot')
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
fig=plt.figure()    #it will create an empty canvus figure
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('Larger plot')

axes2.plot(y,x)
axes2.set_title('Smaller plot')
# Out:
# Text(0.5, 1.0, 'Smaller plot')

# %% [markdown]
# ## Sub plots

# %%
fig, axes = plt.subplots(nrows=2, ncols=3)   #play around changing the number of rows and column
plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=1, ncols=2)
for cu_ax in axes:
    cu_ax.plot(x,y,'r')

# %%
fig,axes=plt.subplots(nrows=1, ncols=2) #arranging plots in rows and column

axes[0].plot(y,x,'r')
axes[0].set_title("The red line")

axes[1].plot(x,y,'g')
axes[1].set_title("The green line")
# Out:
# Text(0.5, 1.0, 'The green line')

# %% [markdown]
# ## Figure Size and DPI
# * `figsize` is a tuple of the width and height of the figure in inches
# * `dpi` is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# %%
fig=plt.figure(figsize=(3,2))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig, axes = plt.subplots(figsize=(3,3))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %% [markdown]
# # Saving Figure
# ### We can use Matplotlib to generate high quality figure in a number formats, including PNG, JPG, EPS, SVG, PGF and PDF.

# %%
fig.savefig("filename.png", dpi=200)

# %% [markdown]
# # Legends, labels and titles

# %%
#Legend

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.legend(loc=3)

# %%
# Lots of options for legend locations

ax.legend(loc=1) # upper right corner
ax.legend(loc=2) # upper left corner
ax.legend(loc=3) # lower left corner
ax.legend(loc=4) # lower right corner
ax.legend(loc=10) # center
ax.legend(loc=0) #let matplotlib to choose location





# Commonly used
ax.legend(loc=0) # let matplotlib decide the optimal location
fig

# %% [markdown]
# ## Plot Appearance

# %%
#using RGB hex code for diffrent colour
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='#FF8C10')

# %%
#using lw or linewidth for thikcer or thiner line
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='#FF8C10',linewidth=8)

# %%
#setting alpha for transparency of the plotted line
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='#FF8C10',linewidth=8, alpha=0.6)

# %%
#using ls or line style for different typs of plotted line
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='violet',lw=5,alpha=0.7,linestyle="-.")

# %%
#markers for every x and y point on the line, it could be circle ,star, plus sign
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='violet',lw=2,alpha=0.7,ls="-",marker="*")

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# # Customising Axis Range

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %% [markdown]
# ## Different Plot using matplotlib

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data,color='green', alpha=0.5)
# Out:
# (array([15.,  9.,  8.,  8., 16.,  6., 11.,  7.,  9., 11.]),
#  array([  5. , 103.1, 201.2, 299.3, 397.4, 495.5, 593.6, 691.7, 789.8,
#         887.9, 986. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x,y)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# ### If you want to larn more about matplotlib follow this link:
#
# http://www.loria.fr/~rougier/teaching/matplotlib
